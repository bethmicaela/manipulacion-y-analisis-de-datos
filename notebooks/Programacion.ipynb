# %% [markdown]
# # ***Introducción***

# %% [markdown]
# ### En la programación todo se resume a datos que representan información. Números, textos, fechas, imágenes, sonidos, vídeos, todo son datos.

# %% [markdown]
# ### `¿Que sentido tiene programar?, ¿cual es su utilidad?`

# %% [markdown]
# ### La programacion es una herramienta para manipular datos de forma automatica.
#
# ### Pero... ¿Que son esos datos? Los datos son informacion, que puede presentarse de muchas formas: Numeros, simbolos, textos, sonidos, imagenes, videos...
#
# ### Esa informacion podemos almacenarla en la memoria de nuestros ordenadores y/o medios digitales

# %% [markdown]
# ### `Informacion manipulable`

# %% [markdown]
# ### Todos los datos quedan guardados en ficheros y bases de datos y con la programacion podemos manipularlo de mil formas

# %% [markdown]
# ### `*   Podemos hacer busquedas de informacion en registros `
#
# ###`*   Para solucionar complejas operaciones matematicas`
#
# ###`*   Para crear formularios y guardar las respuestas`
#
# ###`*   Para dibujar graficos de estos mismos formularios`
#
# ###`*   Incluso darle vida a personajes de un videojuego`

# %% [markdown]
# ### *SIN DATOS LA PROGRAMACION NO TENDRIA SENTIDO*

# %% [markdown]
# ### **Los datos basicos que podemos manejar en python:**
#
#
#
# ### 1.   Números
# ### 2.   Textos
# ### 3.   Listas

# %% [markdown]
# # **`NÚMEROS`**

# %% [markdown]
# Para empezar lo más sencillo es utilizar el intérprete de Python como una calculadora:

# %%
import pandas as pd
import numpy as np

# %%
3 + 2

# %%
3 - 2
# Out:
# 1

# %%
3 * 2
# Out:
# 6

# %%
3 / 2
# Out:
# 1.5

# %%
3 % 2 # Modúlo
# Out:
# 1

# %%
3 ** 2 # Potencia
# Out:
# 9

# %% [markdown]
# **Podemos distinguir 2 tipos de números:**
#
# `Enteros:` Que no tienen una parte decimal y van desde menos infinito a más infinito.
# `Flotantes o decimales:` Números que tienen una parte decimal escrita con un punto.

# %%
1 # Entero
# Out:
# 1

# %%
323239829389.238273283 # Flotante
# Out:
# 323239829389.2383

# %% [markdown]
# **También podemos realizar operaciones más complejas. Python interpretará automáticamente las prioridades de los operadores:**

# %%
3 - 2 + 4 * 10
# Out:
# 41

# %% [markdown]
# # **`VARIABLES`**

# %% [markdown]
# **Este es el concepto más importante en la programación, así que asegúrate de entenderlo bien practicando mucho.**

# %% [markdown]
# ***Concepto fundamental:***
#
# Una variable es un identificador que representa un espacio en la memoria. A este espacio se le puede asignar un valor para utilizarlo posteriormente como si se tratase de un valor literal, inclusos se puede operar con otras variables y reasignarle otro valor en cualquier momento

# %% [markdown]
# **Asignación de un valor a la variable 'n':**

# %%
n = 3
n
# Out:
# 3

# %% [markdown]
# **Suma de una variable entera con un literal número entero:**

# %%
n + 3
# Out:
# 6

# %% [markdown]
# **Producto de una variable entera con un literal número entero:**

# %%
n * 2
# Out:
# 6

# %% [markdown]
# **Producto de una variable entera con un literal número entero:**

# %%
n * n
# Out:
# 9

# %% [markdown]
# **Suma de dos variables enteras:**

# %%
m = 10

n + m
# Out:
# 13

# %% [markdown]
# Producto de dos variables y suma de un literal numérico:

# %%
n * m + 10
# Out:
# 40

# %% [markdown]
# **Reasignación de los valores y cálculo de nuevo resultado:**

# %%
n = 10
m = 15

n + m
# Out:
# 25

# %% [markdown]
# Asignación del valor de una variable a otra:

# %%
n = m
n
# Out:
# 15

# %% [markdown]
# **Incluso se puede asignar una operación mezclada:**

# %%
n = m + 10
n
# Out:
# 25

# %% [markdown]
# **O el propio valor sumado con un literal:**

# %%
n = n + 25
n
# Out:
# 50

# %% [markdown]
# **Reutilización**
#
# Al crear una estructura de cálculos con variables podemos fácilmente adaptar sus valores para hacer distintas comprobaciones:

# %%
nota_1 = 2
nota_2 = 5
nota_media = (nota_1 + nota_2) / 2  # A la suma de ambas las divido en 2

nota_media
# Out:
# 3.5

# %% [markdown]
# # **`CADENAS DE TEXTO`**

# %% [markdown]
# **La función print()**
#
# Es una instrucción que nos permite mostrar correctamente el valor de una cadena (u otros valores/variables) por pantalla:

# %% [markdown]
# **Acepta caracteres especiales como las tabulaciones \t o los saltos de línea \n:**

# %%
print("Un texto \tuna tabulación")
# Out:
# Un texto 	una tabulación

# %%
print("Un texto \nuna nueva línea")
# Out:
# Un texto
# una nueva línea

# %% [markdown]
# **Para evitar los caracteres especiales, debemos indicar que una cadena es cruda (raw):**

# %%
print("C:\nombre\directorio")
# Out:
# C:
# ombre\directorio

# %%
print(r"C:\nombre\directorio")  # r(cadena) => raw (cruda)
# Out:
# C:\nombre\directorio

# %% [markdown]
# Podemos utilizar """ (triple comillas) para cadenas multilínea:

# %%
print("""Una línea
otra línea
otra línea\tuna tabulación""")
# Out:
# Una línea
# otra línea
# otra línea	una tabulación

# %% [markdown]
# **También es posible asignar cadenas a variables. La forma correcta de mostrarlas es con la instrucción print():**

# %%
c = "Esto es una cadena\ncon dos líneas"
c
# Out:
# 'Esto es una cadena\ncon dos líneas'

# %%
c = "Esto es una cadena\ncon dos líneas"
print(c)
# Out:
# Esto es una cadena
# con dos líneas

# %% [markdown]
# # **`OPERACIONES`**

# %% [markdown]
# **Una de las operaciones de las cadenas es la concatenación (o suma de cadenas):**

# %%
c = "Esto es una cadena\ncon dos líneas"
c + c
# Out:
# 'Esto es una cadena\ncon dos líneasEsto es una cadena\ncon dos líneas'

# %%
c = "Esto es una cadena\ncon dos líneas"
print(c+c)
# Out:
# Esto es una cadena
# con dos líneasEsto es una cadena
# con dos líneas

# %% [markdown]
# **También es posible utilizar la multiplicación de cadenas:**

# %%
diez_espacios = " " * 10
print(diez_espacios + "un texto a diez espacios")
# Out:
#           un texto a diez espacios
